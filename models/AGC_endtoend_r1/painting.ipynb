# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import soundfile as sf
import numpy as np

distorted1 = sf.read('/home/yhjeon/projects/IITP_SE/NS_AGC/data/SITEC_AGC/valid/distorted/distorted_4_45501_23117_2.243696616589303.wav')[0]
distorted2 = sf.read('/home/yhjeon/projects/IITP_SE/NS_AGC/data/SITEC_AGC/valid/distorted/distorted_773_3.2681929571744135_0.2508815208183892.wav')[0]
clean1 = sf.read('/home/yhjeon/projects/IITP_SE/NS_AGC/data/SITEC_AGC/valid/original/original_4.wav')[0]
clean2 = sf.read('/home/yhjeon/projects/IITP_SE/NS_AGC/data/SITEC_AGC/valid/original/original_773.wav')[0]

xaxis = np.arange(0, 10, 1/16000)

plt.figure(figsize=[12, 3])
plt.subplot(1, 2, 1)
plt.axis([0, 10, -1.1, 1.1])
plt.plot(xaxis, clean1, color='black')
plt.xlabel('seconds')
plt.title('clean signal')
plt.subplot(1, 2, 2)
plt.axis([0, 10, -1.1, 1.1])
plt.plot(xaxis, distorted1, color='red')
plt.xlabel('seconds')
plt.title('distorted signal')
plt.show()

plt.figure(figsize=[12, 3])
plt.subplot(1, 2, 1)
plt.axis([0, 10, -1.1, 1.1])
plt.plot(xaxis, clean2, color='black')
plt.xlabel('seconds')
plt.title('clean signal')
plt.subplot(1, 2, 2)
plt.axis([0, 10, -1.1, 1.1])
plt.plot(xaxis, distorted2, color='red')
plt.xlabel('seconds')
plt.title('distorted signal')
plt.show()
